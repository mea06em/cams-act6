# %%
from IPython.display import HTML,Javascript, display

# %%
def show_question_1():
    js_code = """
    function showModal() {
        // Create modal element
        var modal = document.createElement('div');
        modal.style.position = 'fixed';
        modal.style.top = '50%';
        modal.style.left = '50%';
        modal.style.transform = 'translate(-50%, -50%)';
        modal.style.backgroundColor = 'white';
        modal.style.border = '1px solid black';
        modal.style.padding = '20px';
        modal.style.boxShadow = '0px 0px 10px rgba(0, 0, 0, 0.1)';
        modal.style.zIndex = '1000';
        modal.style.width = '800px';
        modal.style.height = '200px';
        modal.style.maxWidth = '90%';

        // Add title text (Customizable)
        var title = document.createElement('h2');
        title.innerText = 'Question 1'; // Customized title
        title.style.color = 'black';
        modal.appendChild(title);

        // Add divider line
        var divider = document.createElement('hr');
        divider.style.border = 'none';
        divider.style.borderTop = '1px solid #ddd';
        divider.style.margin = '10px 0'; // Space around the line
        modal.appendChild(divider);

        // Add additional text (Customizable)
        var text = document.createElement('p');
        text.innerText = 'What quantities can be observed from satellites that can be connected to fires?'; // Customized content
        text.style.color = 'black';
        modal.appendChild(text);

        // Add a hyperlink (Customizable)
        var link = document.createElement('a');
        link.href = 'https://app.sli.do/event/5nWynZDd4ZexmQozbYva47/embed/polls/8f07942f-bd05-4dfe-855d-e2e383ba250f'; // Set the link to desired URL
        link.innerText = 'Answer in the poll!';
        link.style.color = 'blue';
        link.style.textDecoration = 'underline';
        link.target = '_blank'; // Open the link in a new tab
        link.rel = 'noopener noreferrer'; // Security measure
        modal.appendChild(link);

        // Add close button
        var closeButton = document.createElement('button');
        closeButton.innerHTML = 'Close';
        closeButton.style.position = 'absolute';
        closeButton.style.top = '10px';
        closeButton.style.right = '10px';
        closeButton.style.backgroundColor = '#f44';
        closeButton.style.color = '#fff';
        closeButton.style.border = 'none';
        closeButton.style.borderRadius = '4px';
        closeButton.style.padding = '5px 10px';
        closeButton.style.cursor = 'pointer';
        closeButton.onclick = function() {
            document.body.removeChild(modal);
        };
        modal.appendChild(closeButton);

        // Append modal to body
        document.body.appendChild(modal);
    }

    // Show the modal
    showModal();
    """

    # Displaying the modal popup using the JavaScript code
    display(Javascript(js_code))

# %%
def show_question_2():
    js_code = """
    function showModal() {
        // Create modal element
        var modal = document.createElement('div');
        modal.style.position = 'fixed';
        modal.style.top = '50%';
        modal.style.left = '50%';
        modal.style.transform = 'translate(-50%, -50%)';
        modal.style.backgroundColor = 'white';
        modal.style.border = '1px solid black';
        modal.style.padding = '20px';
        modal.style.boxShadow = '0px 0px 10px rgba(0, 0, 0, 0.1)';
        modal.style.zIndex = '1000';
        modal.style.width = '800px';
        modal.style.height = '200px';
        modal.style.maxWidth = '90%';

        // Add title text (Customizable)
        var title = document.createElement('h2');
        title.innerText = 'Question 2'; // Customized title
        title.style.color = 'black';
        modal.appendChild(title);

        // Add divider line
        var divider = document.createElement('hr');
        divider.style.border = 'none';
        divider.style.borderTop = '1px solid #ddd';
        divider.style.margin = '10px 0'; // Space around the line
        modal.appendChild(divider);

        // Add additional text (Customizable)
        var text = document.createElement('p');
        text.innerText = 'What can be analysed with Fire Radiative Power (FRP) product?'; // Customized content
        text.style.color = 'black';
        modal.appendChild(text);

        // Add a hyperlink (Customizable)
        var link = document.createElement('a');
        link.href = 'https://app.sli.do/event/5nWynZDd4ZexmQozbYva47/embed/polls/8f07942f-bd05-4dfe-855d-e2e383ba250f'; // Set the link to desired URL
        link.innerText = 'Answer in the poll!';
        link.style.color = 'blue';
        link.style.textDecoration = 'underline';
        link.target = '_blank'; // Open the link in a new tab
        link.rel = 'noopener noreferrer'; // Security measure
        modal.appendChild(link);

        // Add close button
        var closeButton = document.createElement('button');
        closeButton.innerHTML = 'Close';
        closeButton.style.position = 'absolute';
        closeButton.style.top = '10px';
        closeButton.style.right = '10px';
        closeButton.style.backgroundColor = '#f44';
        closeButton.style.color = '#fff';
        closeButton.style.border = 'none';
        closeButton.style.borderRadius = '4px';
        closeButton.style.padding = '5px 10px';
        closeButton.style.cursor = 'pointer';
        closeButton.onclick = function() {
            document.body.removeChild(modal);
        };
        modal.appendChild(closeButton);

        // Append modal to body
        document.body.appendChild(modal);
    }

    // Show the modal
    showModal();
    """

    # Displaying the modal popup using the JavaScript code
    display(Javascript(js_code))

# %%
def show_question_3():
    js_code = """
    function showModal() {
        // Create modal element
        var modal = document.createElement('div');
        modal.style.position = 'fixed';
        modal.style.top = '50%';
        modal.style.left = '50%';
        modal.style.transform = 'translate(-50%, -50%)';
        modal.style.backgroundColor = 'white';
        modal.style.border = '1px solid black';
        modal.style.padding = '20px';
        modal.style.boxShadow = '0px 0px 10px rgba(0, 0, 0, 0.1)';
        modal.style.zIndex = '1000';
        modal.style.width = '800px';
        modal.style.height = '200px';
        modal.style.maxWidth = '90%';

        // Add title text (Customizable)
        var title = document.createElement('h2');
        title.innerText = 'Question 3'; // Customized title
        title.style.color = 'black';
        modal.appendChild(title);

        // Add divider line
        var divider = document.createElement('hr');
        divider.style.border = 'none';
        divider.style.borderTop = '1px solid #ddd';
        divider.style.margin = '10px 0'; // Space around the line
        modal.appendChild(divider);

        // Add additional text (Customizable)
        var text = document.createElement('p');
        text.innerText = 'How to measure intensity of a fire?'; // Customized content
        text.style.color = 'black';
        modal.appendChild(text);

        // Add a hyperlink (Customizable)
        var link = document.createElement('a');
        link.href = 'https://app.sli.do/event/5nWynZDd4ZexmQozbYva47/embed/polls/8f07942f-bd05-4dfe-855d-e2e383ba250f'; // Set the link to desired URL
        link.innerText = 'Answer in the poll!';
        link.style.color = 'blue';
        link.style.textDecoration = 'underline';
        link.target = '_blank'; // Open the link in a new tab
        link.rel = 'noopener noreferrer'; // Security measure
        modal.appendChild(link);

        // Add close button
        var closeButton = document.createElement('button');
        closeButton.innerHTML = 'Close';
        closeButton.style.position = 'absolute';
        closeButton.style.top = '10px';
        closeButton.style.right = '10px';
        closeButton.style.backgroundColor = '#f44';
        closeButton.style.color = '#fff';
        closeButton.style.border = 'none';
        closeButton.style.borderRadius = '4px';
        closeButton.style.padding = '5px 10px';
        closeButton.style.cursor = 'pointer';
        closeButton.onclick = function() {
            document.body.removeChild(modal);
        };
        modal.appendChild(closeButton);

        // Append modal to body
        document.body.appendChild(modal);
    }

    // Show the modal
    showModal();
    """

    # Displaying the modal popup using the JavaScript code
    display(Javascript(js_code))

# %%
def show_question_4():
    js_code = """
    function showModal() {
        // Create modal element
        var modal = document.createElement('div');
        modal.style.position = 'fixed';
        modal.style.top = '50%';
        modal.style.left = '50%';
        modal.style.transform = 'translate(-50%, -50%)';
        modal.style.backgroundColor = 'white';
        modal.style.border = '1px solid black';
        modal.style.padding = '20px';
        modal.style.boxShadow = '0px 0px 10px rgba(0, 0, 0, 0.1)';
        modal.style.zIndex = '1000';
        modal.style.width = '800px';
        modal.style.height = '200px';
        modal.style.maxWidth = '90%';

        // Add title text (Customizable)
        var title = document.createElement('h2');
        title.innerText = 'Question 4'; // Customized title
        title.style.color = 'black';
        modal.appendChild(title);

        // Add divider line
        var divider = document.createElement('hr');
        divider.style.border = 'none';
        divider.style.borderTop = '1px solid #ddd';
        divider.style.margin = '10px 0'; // Space around the line
        modal.appendChild(divider);

        // Add additional text (Customizable)
        var text = document.createElement('p');
        text.innerText = 'How to make sure that the elevated values of Aerosol Optical Depth are coming from smoke emissions?'; // Customized content
        text.style.color = 'black';
        modal.appendChild(text);

        // Add a hyperlink (Customizable)
        var link = document.createElement('a');
        link.href = 'https://app.sli.do/event/5nWynZDd4ZexmQozbYva47/embed/polls/8f07942f-bd05-4dfe-855d-e2e383ba250f'; // Set the link to desired URL
        link.innerText = 'Answer in the poll!';
        link.style.color = 'blue';
        link.style.textDecoration = 'underline';
        link.target = '_blank'; // Open the link in a new tab
        link.rel = 'noopener noreferrer'; // Security measure
        modal.appendChild(link);

        // Add close button
        var closeButton = document.createElement('button');
        closeButton.innerHTML = 'Close';
        closeButton.style.position = 'absolute';
        closeButton.style.top = '10px';
        closeButton.style.right = '10px';
        closeButton.style.backgroundColor = '#f44';
        closeButton.style.color = '#fff';
        closeButton.style.border = 'none';
        closeButton.style.borderRadius = '4px';
        closeButton.style.padding = '5px 10px';
        closeButton.style.cursor = 'pointer';
        closeButton.onclick = function() {
            document.body.removeChild(modal);
        };
        modal.appendChild(closeButton);

        // Append modal to body
        document.body.appendChild(modal);
    }

    // Show the modal
    showModal();
    """

    # Displaying the modal popup using the JavaScript code
    display(Javascript(js_code))

# %%
def show_question_5():
    js_code = """
    function showModal() {
        // Create modal element
        var modal = document.createElement('div');
        modal.style.position = 'fixed';
        modal.style.top = '50%';
        modal.style.left = '50%';
        modal.style.transform = 'translate(-50%, -50%)';
        modal.style.backgroundColor = 'white';
        modal.style.border = '1px solid black';
        modal.style.padding = '20px';
        modal.style.boxShadow = '0px 0px 10px rgba(0, 0, 0, 0.1)';
        modal.style.zIndex = '1000';
        modal.style.width = '800px';
        modal.style.height = '200px';
        modal.style.maxWidth = '90%';

        // Add title text (Customizable)
        var title = document.createElement('h2');
        title.innerText = 'Question 5'; // Customized title
        title.style.color = 'black';
        modal.appendChild(title);

        // Add divider line
        var divider = document.createElement('hr');
        divider.style.border = 'none';
        divider.style.borderTop = '1px solid #ddd';
        divider.style.margin = '10px 0'; // Space around the line
        modal.appendChild(divider);

        // Add additional text (Customizable)
        var text = document.createElement('p');
        text.innerText = 'Why do AOD and AAI maps differ if both show aerosols?'; // Customized content
        text.style.color = 'black';
        modal.appendChild(text);

        // Add a hyperlink (Customizable)
        var link = document.createElement('a');
        link.href = 'https://app.sli.do/event/5nWynZDd4ZexmQozbYva47/embed/polls/8f07942f-bd05-4dfe-855d-e2e383ba250f'; // Set the link to desired URL
        link.innerText = 'Answer in the poll!';
        link.style.color = 'blue';
        link.style.textDecoration = 'underline';
        link.target = '_blank'; // Open the link in a new tab
        link.rel = 'noopener noreferrer'; // Security measure
        modal.appendChild(link);

        // Add close button
        var closeButton = document.createElement('button');
        closeButton.innerHTML = 'Close';
        closeButton.style.position = 'absolute';
        closeButton.style.top = '10px';
        closeButton.style.right = '10px';
        closeButton.style.backgroundColor = '#f44';
        closeButton.style.color = '#fff';
        closeButton.style.border = 'none';
        closeButton.style.borderRadius = '4px';
        closeButton.style.padding = '5px 10px';
        closeButton.style.cursor = 'pointer';
        closeButton.onclick = function() {
            document.body.removeChild(modal);
        };
        modal.appendChild(closeButton);

        // Append modal to body
        document.body.appendChild(modal);
    }

    // Show the modal
    showModal();
    """

    # Displaying the modal popup using the JavaScript code
    display(Javascript(js_code))

# %%
def show_question_6():
    js_code = """
    function showModal() {
        // Create modal element
        var modal = document.createElement('div');
        modal.style.position = 'fixed';
        modal.style.top = '50%';
        modal.style.left = '50%';
        modal.style.transform = 'translate(-50%, -50%)';
        modal.style.backgroundColor = 'white';
        modal.style.border = '1px solid black';
        modal.style.padding = '20px';
        modal.style.boxShadow = '0px 0px 10px rgba(0, 0, 0, 0.1)';
        modal.style.zIndex = '1000';
        modal.style.width = '800px';
        modal.style.height = '200px';
        modal.style.maxWidth = '90%';

        // Add title text (Customizable)
        var title = document.createElement('h2');
        title.innerText = 'Question 6'; // Customized title
        title.style.color = 'black';
        modal.appendChild(title);

        // Add divider line
        var divider = document.createElement('hr');
        divider.style.border = 'none';
        divider.style.borderTop = '1px solid #ddd';
        divider.style.margin = '10px 0'; // Space around the line
        modal.appendChild(divider);

        // Add additional text (Customizable)
        var text = document.createElement('p');
        text.innerText = 'Is there something strange about the IASI CO map?'; // Customized content
        text.style.color = 'black';
        modal.appendChild(text);

        // Add a hyperlink (Customizable)
        var link = document.createElement('a');
        link.href = 'https://app.sli.do/event/5nWynZDd4ZexmQozbYva47/embed/polls/8f07942f-bd05-4dfe-855d-e2e383ba250f'; // Set the link to desired URL
        link.innerText = 'Answer in the poll!';
        link.style.color = 'blue';
        link.style.textDecoration = 'underline';
        link.target = '_blank'; // Open the link in a new tab
        link.rel = 'noopener noreferrer'; // Security measure
        modal.appendChild(link);

        // Add close button
        var closeButton = document.createElement('button');
        closeButton.innerHTML = 'Close';
        closeButton.style.position = 'absolute';
        closeButton.style.top = '10px';
        closeButton.style.right = '10px';
        closeButton.style.backgroundColor = '#f44';
        closeButton.style.color = '#fff';
        closeButton.style.border = 'none';
        closeButton.style.borderRadius = '4px';
        closeButton.style.padding = '5px 10px';
        closeButton.style.cursor = 'pointer';
        closeButton.onclick = function() {
            document.body.removeChild(modal);
        };
        modal.appendChild(closeButton);

        // Append modal to body
        document.body.appendChild(modal);
    }

    // Show the modal
    showModal();
    """

    # Displaying the modal popup using the JavaScript code
    display(Javascript(js_code))
